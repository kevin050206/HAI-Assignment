# %%
from PIL import Image
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

image1 = Image.open('image1.jpg')
image2 = Image.open('image2.jpg')

transform = transforms.ToTensor()

image_tensor1 = transform(image1)
image_tensor2 = transform(image2)

plt.imshow(image_tensor1.permute(1, 2, 0))
plt.show()
plt.imshow(image_tensor2.permute(1, 2, 0))
plt.show()

print(image_tensor1.shape)
print(image_tensor1.dtype)
print(image_tensor2.shape)
print(image_tensor2.dtype)

res1 = image_tensor1 + image_tensor2

plt.imshow(res1.permute(1, 2, 0))
plt.show()

res2 = image_tensor1.matmul(image_tensor2.permute(0, 2, 1))

print(res2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.0].
# torch.Size([3, 2160, 3840])
# torch.float32
# torch.Size([3, 2160, 3840])
# torch.float32
# tensor([[[ 108.3918,  108.3243,  108.6968,  ...,  239.2620,  240.7037,
#            237.8841],
#          [ 108.4798,  108.4194,  108.7935,  ...,  239.3604,  240.9594,
#            237.9957],
#          [ 108.4628,  108.3914,  108.7718,  ...,  239.3310,  241.0712,
#            238.0428],
#          ...,
#          [ 215.1277,  214.5922,  215.7625,  ...,  486.6592,  491.2720,
#            486.3029],
#          [ 214.2501,  213.7468,  214.8846,  ...,  486.2200,  490.6351,
#            485.5405],
#          [ 213.9131,  213.4468,  214.5646,  ...,  486.6104,  490.7686,
#            485.3572]],
#
#         [[ 553.1319,  552.9940,  553.9620,  ...,  359.2445,  361.3168,
#            357.6290],
#          [ 553.0689,  552.9380,  553.9175,  ...,  359.2540,  361.5410,
#            357.6960],
#          [ 553.0753,  552.9379,  553.9289,  ...,  359.3445,  361.8317,
#            357.8768],
#          ...,
#          [ 798.1683,  797.7053,  798.9685,  ...,  518.1946,  521.7994,
#            515.5917],
#          [ 796.3339,  795.9141,  797.1656,  ...,  517.3040,  520.8030,
#            514.4995],
#          [ 795.5803,  795.1780,  796.4039,  ...,  517.1049,  520.3996,
#            513.8345]],
#
#         [[1164.3568, 1164.3302, 1165.7118,  ...,  594.1213,  597.7877,
#            594.7080],
#          [1163.8341, 1163.8094, 1165.1959,  ...,  593.8208,  597.7183,
#            594.4399],
#          [1163.0349, 1162.9948, 1164.3842,  ...,  593.3369,  597.4567,
#            594.0050],
#          ...,
#          [1186.1819, 1186.0676, 1187.3792,  ...,  608.9989,  612.2429,
#            608.1265],
#          [1183.9531, 1183.8763, 1185.1788,  ...,  608.1467,  611.2891,
#            607.0588],
#          [1183.1263, 1183.0732, 1184.3527,  ...,  608.0444,  610.9702,
#            606.4890]]])
